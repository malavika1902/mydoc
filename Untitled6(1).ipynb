# %%
import pandas as pd
df = pd.read_csv("nyc_weather(2).csv")
df.head(10)
df.tail(30)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# ...

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000

# %%
df.Events.describe()
# Out:
# count        9
# unique       3
# top       Rain
# freq         4
# Name: Events, dtype: object

# %%
df.Events.unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.count()
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
df.Temperature.min()
# Out:
# np.int64(20)

# %%
df.Temperature.count()
# Out:
# np.int64(31)

# %%
df.WindSpeedMPH.isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: WindSpeedMPH, dtype: bool

# %%
df.WindSpeedMPH.isna().sum()
# Out:
# np.int64(3)

# %%
df1= df["Temperature"] >10
df1
df1.sum()
# Out:
# np.int64(31)

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
lst=[10,20,30]
s=pd.Series(lst)
print(s,type(s))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
l1=[1,2,3]
s=pd.Series(l1,index=['1st','2nd','3rd'],name='c1')
print(s)
# Out:
# 1st    1
# 2nd    2
# 3rd    3
# Name: c1, dtype: int64

# %%
print(s.loc['1st':'3rd'])
# Out:
# 1st    1
# 2nd    2
# 3rd    3
# Name: c1, dtype: int64

# %%
lst=[10,20,30,40]
s=pd.Series(lst,dtype='float32')
print(s,type(s))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# dtype: float32 <class 'pandas.core.series.Series'>

# %%
s[3]
# Out:
# np.float32(40.0)

# %%
s.shape
# Out:
# (4,)

# %%
l=[10,'rossum',20,'rosie']
print(l)
# Out:
# [10, 'rossum', 20, 'rosie']

# %%
s=pd.Series(l,index=['sd','sf','fr','ju'])
print(s,type(s))
# Out:
# sd        10
# sf    rossum
# fr        20
# ju     rosie
# dtype: object <class 'pandas.core.series.Series'>

# %%
s['sf']
# Out:
# 'rossum'

# %%
d1={"s1":"python","s2":"java","s3":"ml"}
print(d1,type(d1))
# Out:
# {'s1': 'python', 's2': 'java', 's3': 'ml'} <class 'dict'>

# %%
d1.items()
# Out:
# dict_items([('s1', 'python'), ('s2', 'java'), ('s3', 'ml')])

# %%
lst=[[1,0,1,3],[2,1,3,0],[2,3,5,4]]
df=pd.Series(lst)
print(df)
# Out:
# 0    [1, 0, 1, 3]
# 1    [2, 1, 3, 0]
# 2    [2, 3, 5, 4]
# dtype: object

# %%
lst=[[1,0,1,3],[2,1,3,0],[2,3,5,4]]
df=pd.DataFrame(lst)
print(df)
# Out:
#    0  1  2  3
# 0  1  0  1  3
# 1  2  1  3  0
# 2  2  3  5  4

# %%
df.iloc[1:,:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# ...

# %%
df.loc[1:,:]
# Out:
#    0  1  2  3
# 1  2  1  3  0
# 2  2  3  5  4

# %%
df.iloc[2,2]
# Out:
# np.int64(5)

# %%
lst=[[1,0,1,3],[2,1,3,0],[2,3,5,4]]
df=pd.DataFrame(lst,columns=['rn','nm','gh','po'],index=[20,30,40])
print(df)
# Out:
#     rn  nm  gh  po
# 20   1   0   1   3
# 30   2   1   3   0
# 40   2   3   5   4

# %%
import pandas as pd
tple = (('rossum',32),('fgy',84),('eed',34))
df=pd.DataFrame(tple,index=[1,2,3],columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 1  rossum   32
# 2     fgy   84
# 3     eed   34

# %%
dictdata={"names":["rose","mary","loly","mick"],"subjects":["python","java","ml","c"],"ages":[23,45,56,67]}
#dictdata.values()
print(dictdata)
# Out:
# {'names': ['rose', 'mary', 'loly', 'mick'], 'subjects': ['python', 'java', 'ml', 'c'], 'ages': [23, 45, 56, 67]}

# %%
df=pd.DataFrame(dictdata)
print(df)
# Out:
#   names subjects  ages
# 0  rose   python    23
# 1  mary     java    45
# 2  loly       ml    56
# 3  mick        c    67

# %%
df.shape
# Out:
# (4, 3)

# %%
df=pd.DataFrame(dictdata,index=[1,2,3,'e'])
print(df)
# Out:
#   names subjects  ages
# 1  rose   python    23
# 2  mary     java    45
# 3  loly       ml    56
# e  mick        c    67

# %%
l1=[10,20,30]
sdata=pd.Series(l1)
print(sdata,type(sdata))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
df=pd.DataFrame(sdata,columns=["number"])
print(df)
# Out:
#    number
# 0      10
# 1      20
# 2      30

# %%
df.shape
# Out:
# (3, 1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
d1={"totmark":[100,110,120],"exmark":[20,30,40]}
df=pd.DataFrame(d1,index=[1,2,3])
(df)
# Out:
#    totmark  exmark
# 1      100      20
# 2      110      30
# 3      120      40

# %%
df.loc[2:,:]
# Out:
#    totmark  exmark
# 2      110      30
# 3      120      40

# %%
df.iloc[2:]
# Out:
#    totmark  exmark
# 3      120      40

# %%
#add is a new column name
df['c3']=df['totmark'] + df['exmark']
df
# Out:
#    totmark  exmark   c3
# 1      100      20  120
# 2      110      30  140
# 3      120      40  160

# %%
df['c3']=df['totmark']-df['exmark']
df
# Out:
#    totmark  exmark  c3
# 1      100      20  80
# 2      110      30  80
# 3      120      40  80

# %%
df['newcol']=[1,3,5]
df
# Out:
#    totmark  exmark  c3  newcol
# 1      100      20  80       1
# 2      110      30  80       3
# 3      120      40  80       5

# %%
df['rollno']=range(1,4)
df
# Out:
#    totmark  exmark  c3  newcol  rollno
# 1      100      20  80       1       1
# 2      110      30  80       3       2
# 3      120      40  80       5       3

# %%
#changing col order
df=df[['rollno','totmark','newcol','c3','exmark']]
df
# Out:
#    rollno  totmark  newcol  c3  exmark
# 1       1      100       1  80      20
# 2       2      110       3  80      30
# 3       3      120       5  80      40

# %%
df1=df[['rollno','totmark']]
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df1=df[['rollno','totmark']]
#       2 df1
#
# File C:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Program Files\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
#sorting dataframe data
df=df.sort_values(['exmark'],ascending=True)
df
# Out:
#   Cell In[21], line 2
#     df=df.sort_values(exmark.ascending=True)
#                       ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df=df.sort_values(['exmark'],ascending=False)
df
# Out:
#    rollno  totmark  newcol  c3  exmark
# 3       3      120       5  80      40
# 2       2      110       3  80      30
# 1       1      100       1  80      20

# %%
df.to_html('b')
df
# Out:
#    totmark  exmark   c3
# 1      100      20  120
# 2      110      30  140
# 3      120      40  160

# %%
import pandas as pd
df=pd.read_csv('data(1).csv')
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df=df.sort_values(['team1'],ascending=True)
df
# Out:
#       id  season        city        date                team1  \
# 467  468    2015     Kolkata  2015-04-30  Chennai Super Kings
# 134  135    2010      Mumbai  2010-03-25  Chennai Super Kings
# 57    58    2008      Mumbai  2008-06-01  Chennai Super Kings
# 394  395    2013       Delhi  2013-05-21  Chennai Super Kings
# 183  184    2011  Chandigarh  2011-04-13  Chennai Super Kings
# ..   ...     ...         ...         ...                  ...
# 389  390    2013   Hyderabad  2013-05-17  Sunrisers Hyderabad
# 384  385    2013      Mumbai  2013-05-13  Sunrisers Hyderabad
# 543  544    2016   Hyderabad  2016-04-30  Sunrisers Hyderabad
# 372  373    2013   Bangalore  2013-04-09  Sunrisers Hyderabad
# 576  577    2016   Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 467        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %% [markdown]
# ### df=df.sort_values(['team1'],ascending=False)
# df

# %%
df['city'].count()
# Out:
# np.int64(570)

# %%
df['player_of_match']
# Out:
# 576       BCJ Cutting
# 501      MC Henriques
# 484          TA Boult
# 508           V Kohli
# 491         DA Warner
#             ...
# 292          SK Raina
# 109    M Muralitharan
# 287         G Gambhir
# 1          MEK Hussey
# 467        AD Russell
# Name: player_of_match, Length: 577, dtype: object

# %%
#astype- it is used to change from one datatype to another
df['id']=df['id'].astype('float') #astype
df.dtypes
# Out:
# id                 float64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df['winner']
# Out:
# 576            Sunrisers Hyderabad
# 501            Sunrisers Hyderabad
# 484            Sunrisers Hyderabad
# 508    Royal Challengers Bangalore
# 491            Sunrisers Hyderabad
#                   ...
# 292            Chennai Super Kings
# 109            Chennai Super Kings
# 287          Kolkata Knight Riders
# 1              Chennai Super Kings
# 467          Kolkata Knight Riders
# Name: winner, Length: 577, dtype: object

# %%
df['winner'],[df['player_of_match']== 'V Kohli']
# Out:
# (576            Sunrisers Hyderabad
#  501            Sunrisers Hyderabad
#  484            Sunrisers Hyderabad
#  508    Royal Challengers Bangalore
#  491            Sunrisers Hyderabad
#                    ...
#  292            Chennai Super Kings
#  109            Chennai Super Kings
#  287          Kolkata Knight Riders
#  1              Chennai Super Kings
#  467          Kolkata Knight Riders
#  Name: winner, Length: 577, dtype: object,
#  [576    False
#   501    False
#   484    False
#   508     True
#   491    False
#          ...
#   292    False
#   109    False
#   287    False
#   1      False
#   467    False
#   Name: player_of_match, Length: 577, dtype: bool])

# %%
df['umpire3']=df['umpire3'].fillna('Switzerland')
df
# Out:
#         id  season        city        date                team1  \
# 576  577.0    2016   Bangalore  2016-05-29  Sunrisers Hyderabad
# 501  502.0    2015      Raipur  2015-05-09  Sunrisers Hyderabad
# 484  485.0    2015  Chandigarh  2015-04-27  Sunrisers Hyderabad
# 508  509.0    2015   Hyderabad  2015-05-15  Sunrisers Hyderabad
# 491  492.0    2015   Hyderabad  2015-05-02  Sunrisers Hyderabad
# ..     ...     ...         ...         ...                  ...
# 292  293.0    2012     Chennai  2012-05-04  Chennai Super Kings
# 109  110.0    2009      Durban  2009-05-20  Chennai Super Kings
# 287  288.0    2012     Chennai  2012-04-30  Chennai Super Kings
# 1      2.0    2008  Chandigarh  2008-04-19  Chennai Super Kings
# 467  468.0    2015     Kolkata  2015-04-30  Chennai Super Kings
#
#                            team2            toss_winner toss_decision  result  \
# 576  Royal Challengers Bangalore    Sunrisers Hyderabad           bat  normal
# ...

# %%
df.loc[1:,:]
# Out:
#       id  season        city        date                team1  \
# 1      2    2008  Chandigarh  2008-04-19  Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19     Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20       Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20      Deccan Chargers
# 5      6    2008      Jaipur  2008-04-21      Kings XI Punjab
# ..   ...     ...         ...         ...                  ...
# 572  573    2016      Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016       Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27        Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 1                Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
df.iloc[1:15]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.iloc[1:15]
#
# NameError: name 'df' is not defined
